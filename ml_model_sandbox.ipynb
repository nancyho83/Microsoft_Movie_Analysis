# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
conn = sqlite3.connect("data\movies.db")
cur = conn.cursor()

# %%
rotten_tomatoes_df = pd.read_sql("SELECT * FROM rotten_tomatoes_movies", conn)
rotten_tomatoes_df.head()
# Out:
#    idx                   rotten_tomatoes_link  \
# 0    0                              m/0814255
# 1    1                              m/0878835
# 2    2                                   m/10
# 3    3                 m/1000013-12_angry_men
# 4    4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
# ...

# %%
tn_budgets_df = pd.read_sql("SELECT * FROM tn_movie_budgets", conn)
tn_budgets_df.set_index('idx', inplace=True)
tn_budgets_df.head()
# Out:
#      id  release_date                                        movie  \
# idx
# 0     1  Dec 18, 2009                                       Avatar
# 1     2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2     3   Jun 7, 2019                                 Dark Phoenix
# 3     4   May 1, 2015                      Avengers: Age of Ultron
# 4     5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#     production_budget domestic_gross worldwide_gross
# idx
# 0        $425,000,000   $760,507,625  $2,776,345,279
# 1        $410,600,000   $241,063,875  $1,045,663,875
# 2        $350,000,000    $42,762,350    $149,762,350
# 3        $330,600,000   $459,005,868  $1,403,013,963
# 4        $317,000,000   $620,181,382  $1,316,721,747

# %%
bom_gross_df = pd.read_sql("SELECT * FROM bom_movie_gross", conn)
bom_gross_df.set_index('idx', inplace=True)
bom_gross_df.head()
# Out:
#                                            title studio  domestic_gross  \
# idx
# 0                                    Toy Story 3     BV     415000000.0
# 1                     Alice in Wonderland (2010)     BV     334200000.0
# 2    Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                      Inception     WB     292600000.0
# 4                            Shrek Forever After   P/DW     238700000.0
#
#     foreign_gross  year
# idx
# 0       652000000  2010
# 1       691300000  2010
# 2       664300000  2010
# 3       535700000  2010
# 4       513900000  2010

# %%
imdb_basics_df = pd.read_sql("SELECT * FROM imdb_title_basics", conn)
imdb_basics_df.set_index('idx', inplace=True)
imdb_basics_df.head()
# Out:
#         tconst                    primary_title              original_title  \
# idx
# 0    tt0063540                        Sunghursh                   Sunghursh
# 1    tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2    tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3    tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4    tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#      start_year  runtime_minutes                genres
# idx
# 0          2013            175.0    Action,Crime,Drama
# 1          2019            114.0       Biography,Drama
# 2          2018            122.0                 Drama
# 3          2018              NaN          Comedy,Drama
# 4          2017             80.0  Comedy,Drama,Fantasy

# %%
bom_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 158.8+ KB

# %%
bom_gross_df['foreign_gross'] = bom_gross_df['foreign_gross'].str.replace(',','').astype(float)

# %%
bom_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   float64
#  4   year            3387 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 158.8+ KB

# %%
tn_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 316.2+ KB

# %%
tn_budgets_df['production_budget'] = tn_budgets_df['production_budget'].map(lambda x: x.lstrip('$'))
tn_budgets_df.head()
# Out:
#      id  release_date                                        movie  \
# idx
# 0     1  Dec 18, 2009                                       Avatar
# 1     2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2     3   Jun 7, 2019                                 Dark Phoenix
# 3     4   May 1, 2015                      Avengers: Age of Ultron
# 4     5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#     production_budget domestic_gross worldwide_gross
# idx
# 0         425,000,000   $760,507,625  $2,776,345,279
# 1         410,600,000   $241,063,875  $1,045,663,875
# 2         350,000,000    $42,762,350    $149,762,350
# 3         330,600,000   $459,005,868  $1,403,013,963
# 4         317,000,000   $620,181,382  $1,316,721,747

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from imblearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, plot_confusion_matrix
